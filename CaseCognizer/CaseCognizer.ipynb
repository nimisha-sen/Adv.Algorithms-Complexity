# %% [markdown]
# ### Project: CaseCognizer

# %%
import csv

# Function to open a CSV file and return fields and rows
def open_csv_file(file_name):
    print("Opened a new CSV file: " + str(file_name))
    
    # Initializing the titles and rows list
    fields = []
    rows = []
    
    # Reading CSV file
    with open(file_name, 'r') as csvfile:
        # Creating a CSV reader object
        csvreader = csv.reader(csvfile)
        
        # Extracting field names from the first row
        fields = next(csvreader)
    
        # Extracting each data row one by one
        for row in csvreader:
            rows.append(row)
    
        # Get the total number of rows
        print("Total no. of rows: %d" % (csvreader.line_num))
    
    # Printing the field names
    print('Field names are: ' + ', '.join(field for field in fields))
    print('\n')
    return [fields, rows]

# Function to get the length of the first column value
def get_length_of_first_column(row):
    return len(row[0])

# Function to perform Job Sequencing Greedy algorithm
def job_sequencing(rows, max_deadline):
    # Sort the rows based on the length of the first column in descending order
    sorted_rows = sorted(rows, key=get_length_of_first_column, reverse=True)

    # Initialize variables for the schedule and set to store selected jobs
    schedule = [-1] * len(sorted_rows)
    job_set = set()
    rejected_jobs = []

    # Fill the schedule
    for row in sorted_rows:
        deadline = int(row[1])  # Assuming the deadline is in the second column
        if deadline <= max_deadline:
            for i in range(min(len(schedule) - 1, deadline - 1), -1, -1):
                if schedule[i] == -1:
                    schedule[i] = tuple(row)  # Convert the list to a tuple
                    job_set.add(tuple(row))   # Convert the list to a tuple
                    break
        else:
            rejected_jobs.append(tuple(row))

    return list(job_set), rejected_jobs

# Main program
# used a __name__ check to ensure that the main program code is only executed 
# when the script is run directly, not when it is imported as a module.
if __name__ == "__main__": 
    # Open the main file (Before merge)
    res = open_csv_file('notsorted_excel_legal.csv')
    fields = res[0]
    rows = res[1]

    # Apply merge sort on rows based on length of the first column (Report length)
    sorted_rows = sorted(rows, key=get_length_of_first_column)

    # Writing the sorted rows to a new CSV file
    with open("LegalDocs_sorted_by_len.csv", 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(fields)
        csvwriter.writerows(sorted_rows)

    # Open the new file
    res = open_csv_file('LegalDocs_sorted_by_len.csv')
    fields = res[0]
    rows = res[1]

    # Perform Job Sequencing
    max_deadline_chosen = 3
    selected_jobs, rejected_jobs = job_sequencing(rows, max_deadline_chosen)

    # Display selected jobs
    print("Selected Jobs which have a deadline of " + str(max_deadline_chosen) + " days:")
    for job in selected_jobs:
        print(job)

    print("Rejected Jobs which have a deadline of " + str(max_deadline_chosen) + " days:")
    for job in rejected_jobs:
        print(job)

    # Now, classify from array how many times each word has appeared
    to_find_word_arr = ['biotech', 'real-estate', 'house']

    for job in selected_jobs:
        first_column_words = job[0].split()  # We assume words are separated by space
        word_count = {word: 0 for word in to_find_word_arr}  # Initialize word count dictionary
    
        # Lower() is used to convert to lower cases to avoid any mismatches
        for word in first_column_words:
            if word.lower() in to_find_word_arr:
                word_count[word.lower()] += 1  # Increment if found to be matching
    
        # Display the first 128 chars in print
        print("\nWord count for job:", job[0:128])
        for word, count in word_count.items():
            print(f"{word}: {count} instances")
# Out:
# Opened a new CSV file: notsorted_excel_legal.csv
# Total no. of rows: 5
# Field names are: Reports, Deadline(Days), Payment($)
#
#
# Opened a new CSV file: LegalDocs_sorted_by_len.csv
# Total no. of rows: 5
# Field names are: Reports, Deadline(Days), Payment($)
#
#
# Selected Jobs which have a deadline of 3 days:
# ('apple apple orange real-estate', '1', '20')
# ...

# %% [markdown]
# #### Output:
#
# - CSV File Processing:
#     - The program successfully opens the initial CSV file (notsorted_excel_legal.csv) and the sorted CSV file (LegalDocs_sorted_by_len.csv).
#     - It prints the total number of rows and the field names for each file.
# - Job Sequencing:
#     - The program applies a job sequencing algorithm to select jobs with a deadline of 3 days or less. It prints the selected jobs and rejected jobs based on their deadlines.
# - Word Processing:
#     - The program counts the occurrences of specific words in the selected jobs.
#     - Word count for Job 1 - ('exp exp exp biotech biotech biotech biotech'): biotech: 4 instances
#
# #### Next Steps:
# - File Format Flexibility:
#     Implement functionality to handle different file formats, such as xml.
#
# - Graphical Representation:
#     Utilize a data visualization library like Matplotlib or Seaborn to create graphical representations of relevant data. This could include visualizing word occurrences, job deadlines, or other key metrics.
#
# - Sentiment Analysis:
#     Integrate an NLP library (e.g., spaCy, NLTK) or pre-trained models for sentiment analysis. Analyzing the sentiment of legal documents can provide valuable insights into the tone and context of the content.
#
# - **Machine Learning for Relevance Ranking:**
#     Consider implementing machine learning models for relevance ranking. Train a model on labeled data to predict the relevance of legal documents to specific research topics. This could involve features like word frequency, sentiment, or document structure.
#
# - User Interface:
#     Develop a user-friendly interface to interact with your program. This could be a web-based dashboard or a desktop application. A well-designed interface will make it easier to input data, visualize results, and interpret findings.
#
# - Documentation and Testing:
#    Keep on adding and brainstorming algorithms that can be effectively be used. Implement comprehensive testing to catch bugs and validate the correctness of the algorithms.
#
# - Collaboration and Feedback:
#     Consider sharing your project with peers, mentors, or online communities to receive feedback. Collaborating with others can bring new perspectives and ideas, and feedback can help you refine and improve your project.
#
# - Implementation of AI Models:
#     Proceed with implementing AI models for sentiment analysis and explore other AI applications in the legal tech sector. This might involve natural language processing, machine learning, or even deep learning, depending on the complexity of the tasks.
#
# - Continuous Improvement:
#     Keep refining and expanding the project based on feedback and with my evolving understanding of the domain. Stay informed about new technologies and advancements in legal tech and AI.

# %% [markdown]
# #### Algorithms being used:
# Quick Sort Algorithm (implicitly used):
#     Used to sort csv rows based on its length. However, the actual sorting implementation is done using Python's built-in sorted function, which uses Timsort (a hybrid sorting algorithm derived from merge sort and insertion sort).
#
# Greedy Job Sequencing Algorithm:
#     The job_sequencing function implements a greedy algorithm for job sequencing. The goal is to process the most important legal document first by maximizing the amount and minimizing the deadline. This algorithm sorts the jobs based on the length of the first column in descending order and then schedules them based on their deadlines.
#
# Word Processing Algorithm:
#     The code processes selected jobs and classifies how many times each word from the specified list (to_find_word_arr) appears in the first column of the job. It uses a simple word count algorithm, iterating through the words in the column and checking for matches with the specified words in the list.
#
# CSV File Handling:
#     The code uses the csv module to read and write CSV files. It extracts field names, reads rows from a CSV file, sorts rows, and writes the sorted rows to a new CSV file.
